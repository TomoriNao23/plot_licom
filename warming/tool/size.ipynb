# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
path = "/home/yyq/mls/dataprocess/warming/photo/delta_sst.png"
img = Image.open(path)

print(img.size)
rect = (0, 165, 1024, 810)
crop_image = img.crop(rect)
crop_image.save(path)
# Out:
# (1024, 1024)

# %%
img_out = Image.open(path)
plt.figure(figsize=(10, 10))
plt.axis('off')
plt.imshow(img_out)
plt.show()
