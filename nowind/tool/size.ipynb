# %% [markdown]
# #### <center>__风应力敏感性试验__
# ##### 图(1)海表面sst和sss变化
# ##### 图(2)sst和sss变化的垂直剖面
# ##### 图(3)不同纬度sst和sss变化的垂直剖面
# ##### 图(4)正压流函数bsf变化

# %%
from tool.size import act

# %%
act0 =act("nowind/photo/sst_sss.png",(0, 355, 1024, 665))
act0.size_change()
act0.save()
# Out:
# (1024, 1024)

# %%
act1 =act("nowind/photo/depth.png",(0, 155, 1024, 865))
act1.figs = (10, 10)
act1.size_change()
act1.save()
# Out:
# (1024, 1024)

# %%
act2 =act("nowind/photo/depth2.png",(0, 340, 1024, 680))
act2.size_change()
act2.save()
# Out:
# (1024, 1024)

# %%
act3 =act("nowind/photo/bsf.png",(0, 165, 1024, 775))
act3.figs = (8, 8)
act3.size_change()
act3.save()
# Out:
# (1024, 1024)
