# %% [markdown]
# #### <center>__淡水通量实验__
# ##### 图(1)低纬度存在净辐射盈余，故需要海洋正热输送来抵消。而高纬度存在净辐射亏损，故需要海洋热输送来弥补。经向热输送在大洋西边界存在大值即西边界流
# ##### 图(2)进行纬向平均可知AMOC是北半球最主要的海洋经向热输送，最大值出现在30N附近
# ##### 图(3)北大西洋添加淡水后，上层经向流函数减弱，AMOC减弱，低纬度暖且高密度海水向高纬度输送减弱
# ##### 图(4)AMOC减弱最终导致北大西洋出现负海表温度和海水变淡

# %%
from tool.size import act

# %%
act0 =act("addwater/photo/heat.png",(0, 355, 1024, 665))
act0.size_change()
act0.save()
# Out:
# (1024, 1024)

# %%
act1 = act("addwater/photo/heat_lat.png",(0, 340, 1024, 685))
act1.size_change()
act1.save()
# Out:
# (1024, 1024)

# %%
act2 = act("addwater/photo/delta_psi.png",(0, 135, 1024, 805))
act2.figs = (8, 8)
act2.size_change()
act2.save()
# Out:
# (1024, 1024)

# %%
act0 =act("addwater/photo/sst_sss.png",(0, 355, 1024, 665))
act0.size_change()
act0.save()
# Out:
# (1024, 1024)
